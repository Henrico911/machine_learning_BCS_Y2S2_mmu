# %%
# libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def load_data(fliepath: str):
    df = pd.read_csv(filepath)
    return df

# %%
filepath = "/home/karamagi/Computer Science/BCS_Y2/YEAR TWO SEMSTER TWO/machine_learning/code/26 feb/data.csv"

load_data(filepath)
# Out:
#                                                  English  \
# 0      Rwenzori Mountains are located in western Uganda.
# 1        Queen Elizabeth Park is known for its wildlife.
# 2                        What is Kasese town famous for?
# 3      The river in Kasese is called the Nyamwamba Ri...
# 4               Mount Rwenzori's height is 5,109 meters.
# ...                                                  ...
# 15080  lessons learnt are being revised to improve Eb...
# 15081  people are now employing people who are below ...
# 15082     people do not know how to control their temper
# 15083  the Uganda Martyrs that were killed were not o...
# 15084    you have a right to plead not guilty in a court
#
#                                                  Rutooro  \
# 0      Ensozi za Rwenzori nizisangwa bugwaizooba bwa ...
# 1      Ekisaka kya Queen Elizabeth kimanyirwe habw'ob...
# 2           Orubuga rwa Kasese rumanyirwehoki ekyamaani?
# ...

# %%
# Basic analysis
def analyse_data(df):
    dataset_info = {
        
    }
